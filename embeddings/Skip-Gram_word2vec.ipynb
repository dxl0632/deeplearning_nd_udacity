# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:09, 3.21MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
np.random.uniform?
http://mccormickml.com/2017/01/11/word2vec-tutorial-part-2-negative-sampling/

# %%
int_words[:10]
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155]

# %%
## Your code here
from collections import Counter
import random

count = Counter(int_words)
tot = sum(count)
freq = {k: (v / tot) for k, v in count.items()}

np.random.seed(632)
t = 1e-5
p_discard = {word: 1 - np.sqrt(t/freq[word]) for word in int_words}
train_words = [word for word in int_words if random.random() < (1 - p_discard[word])]

# %%
len(train_words)
# Out:
# 11917971

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
random.sample?

# %%
random.sample(range(1, 6), 1)
# Out:
# [4]

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    new_size = random.sample(range(1, window_size + 1), 1)[0]
    left_index = idx - new_size
    right_index = idx + new_size + 1
    if left_index < 0 :
        left_index = 0
    return words[left_index: idx] + words[idx: right_index]

# %%
# # test
# words = [1, 2, 3, 4, 5, 6, 7, 8]
# idx = 1
# window_size = 4
# get_target(words, idx, window_size)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
tf.reset_default_graph()
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300# Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 7.2813 0.4983 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 6.9801 0.4415 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.8036 0.5112 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 6.4825 0.4908 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 6.1445 0.4470 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.7863 0.5099 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5054 0.5071 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.2643 0.4933 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.2859 0.5042 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.1517 0.5011 sec/batch
# Nearest to while: strength, recover, majority, carries, beas, bears, revolt, non,
# Nearest to eight: twenty, holocaust, proclaimed, homestead, th, jesse, resonance, hindsight,
# Nearest to other: countries, chopsticks, ancient, example, sell, proximity, shareholders, xu,
# Nearest to these: isbn, muppet, tenn, cairo, fluctuated, ecuador, hecuba, propositions,
# Nearest to where: safely, pavilion, legumes, appeared, coconut, inspiration, caliphates, metcalfe,
# Nearest to people: that, many, refuse, assemble, brought, ud, sphere, heinrich,
# Nearest to will: mwi, top, need, machines, structure, divorced, metropolitans, hedgehogs,
# Nearest to b: stood, haldane, found, first, press, abh, density, replacement,
# Nearest to road: headline, intergalactic, gerrymandering, milder, backwardness, veneto, things, extending,
# Nearest to police: vital, son, stool, hbt, playmate, indeed, fon, quantity,
# Nearest to http: xico, palo, affairs, igg, assemblee, mandrakesoft, myles, deeply,
# Nearest to arts: account, bayan, event, marrying, pedagogue, augustinians, implicates, cognitively,
# Nearest to shows: output, possible, pickover, motors, previous, sole, bobble, ambrose,
# Nearest to engineering: added, miscarriage, rarely, bishops, practices, totally, mini, catholic,
# Nearest to channel: spells, jesuit, tales, despise, taken, coates, formulas, monoclonal,
# Nearest to shown: economists, lewis, influential, dora, abandonment, thence, sanctify, job,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.0556 0.5200 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.0022 0.5068 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.9187 0.4238 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.8939 0.4146 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.8510 0.4042 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.8479 0.4169 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.7959 0.4800 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.7162 0.5159 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.7577 0.5147 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.7377 0.5155 sec/batch
# Nearest to while: strength, majority, recover, forced, carries, blog, hemorrhage, beas,
# Nearest to eight: jesse, holocaust, proclaimed, hindsight, homestead, twenty, ton, kids,
# Nearest to other: countries, sell, capillaries, chopsticks, shareholders, example, xu, ancient,
# Nearest to these: muppet, cairo, tenn, fluctuated, folded, isbn, ecuador, propositions,
# Nearest to where: pavilion, safely, legumes, eligible, coconut, inspiration, appeared, cdot,
# Nearest to people: that, refuse, many, vital, assemble, planners, masterpieces, sphere,
# Nearest to will: mwi, need, divorced, machines, timur, top, pineapples, metropolitans,
# Nearest to b: stood, haldane, first, replacement, found, abh, lego, assists,
# Nearest to road: headline, intergalactic, milder, veneto, automobile, extending, polypropylene, gerrymandering,
# Nearest to police: vital, stool, fon, residences, quantity, playmate, hbt, denouncing,
# Nearest to http: xico, affairs, palo, polymer, igg, assemblee, noaa, turret,
# Nearest to arts: event, bayan, account, marrying, barry, pedagogue, umami, cognitively,
# Nearest to shows: output, gangster, sole, motors, pickover, bobble, sensuous, hyakutake,
# Nearest to engineering: added, rarely, mini, miscarriage, bishops, practices, rum, totally,
# Nearest to channel: spells, tales, jesuit, despise, coates, monoclonal, jaime, taken,
# Nearest to shown: economists, circulatory, dora, abandonment, lewis, influential, default, generation,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.7211 0.5367 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.6603 0.5143 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.6412 0.5297 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.6918 0.5187 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.6471 0.5168 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.6186 0.5389 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.5918 0.5038 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.5664 0.4248 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.5127 0.4011 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.5038 0.4060 sec/batch
# Nearest to while: strength, recover, majority, genoa, fluorspar, blog, unionist, revolt,
# Nearest to eight: jesse, hindsight, ton, homestead, proclaimed, tre, twenty, holocaust,
# Nearest to other: countries, sell, capillaries, shareholders, chopsticks, xu, pulsating, justify,
# Nearest to these: muppet, fluctuated, cairo, nodes, propositions, tenn, folded, deduced,
# Nearest to where: pavilion, safely, legumes, eligible, inspiration, coconut, cdot, labrador,
# Nearest to people: many, that, refuse, planners, vital, reconciled, sphere, ud,
# Nearest to will: need, mwi, pineapples, timur, top, divorced, periodical, metropolitans,
# Nearest to b: stood, haldane, replacement, first, dwellers, metaphor, found, mausoleum,
# Nearest to road: headline, intergalactic, milder, logging, gerrymandering, automobile, veneto, backwardness,
# Nearest to police: vital, stool, fon, playmate, hbt, residences, livre, jupiter,
# Nearest to http: xico, palo, affairs, polymer, myles, assemblee, igg, www,
# Nearest to arts: bayan, event, marrying, pedagogue, barry, account, cognitively, implicates,
# Nearest to shows: gangster, bobble, output, pickover, sole, sensuous, ambrose, previous,
# Nearest to engineering: miscarriage, rarely, added, mini, bishops, practices, rhoda, overtime,
# Nearest to channel: spells, tales, despise, jesuit, coates, monoclonal, formulas, milestone,
# Nearest to shown: dora, economists, sanctify, circulatory, abandonment, shehhi, beta, bacterial,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.5540 0.4640 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.5134 0.4461 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.5168 0.4161 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.5465 0.4767 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.5453 0.5552 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.4338 0.4559 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.5488 0.4153 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.5009 0.4151 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.5034 0.4107 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.4889 0.4130 sec/batch
# Nearest to while: strength, recover, genoa, fluorspar, forced, hemorrhage, logically, majority,
# Nearest to eight: jesse, twenty, hindsight, stumbled, rudolph, tre, homestead, ton,
# Nearest to other: countries, sell, capillaries, chopsticks, xu, pulsating, methuen, shareholders,
# Nearest to these: muppet, fluctuated, nodes, folded, tenn, codify, propositions, cairo,
# Nearest to where: legumes, pavilion, safely, coconut, cdot, inspiration, eligible, labrador,
# Nearest to people: many, refuse, planners, that, vital, china, reconciled, ud,
# Nearest to will: need, mwi, periodical, symbionts, divorced, axial, vibrant, timur,
# Nearest to b: stood, haldane, replacement, accumulating, mausoleum, girard, found, abh,
# Nearest to road: headline, intergalactic, milder, logging, veneto, gerrymandering, automobile, kvar,
# Nearest to police: vital, denouncing, jupiter, stool, hbt, dhabi, playmate, fon,
# Nearest to http: xico, www, palo, myles, mandrakesoft, noaa, affairs, igg,
# Nearest to arts: barry, bayan, event, pedagogue, marrying, plaster, cognitively, ovum,
# Nearest to shows: gangster, pickover, bobble, output, sensuous, nader, hyakutake, ambrose,
# Nearest to engineering: miscarriage, overtime, rarely, mini, rhoda, added, reviews, entertain,
# Nearest to channel: tales, spells, jesuit, despise, coates, collusion, monoclonal, shootouts,
# Nearest to shown: dora, economists, sanctify, roadways, circulatory, shehhi, bacterial, apparition,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.4451 0.4107 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.4649 0.4130 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5110 0.4175 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.4331 0.4124 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.4631 0.4126 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.3961 0.4061 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.4766 0.3767 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.4596 0.4118 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.4470 0.4127 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.4661 0.4149 sec/batch
# Nearest to while: strength, recover, hemorrhage, hunts, fluorspar, genoa, bocks, blog,
# Nearest to eight: jesse, hindsight, twenty, tre, stumbled, seedy, rudolph, devolution,
# Nearest to other: countries, capillaries, sell, xu, chopsticks, methuen, pulsating, ora,
# Nearest to these: codify, muppet, fluctuated, rohmer, gifts, nodes, tenn, trois,
# Nearest to where: cdot, legumes, pavilion, safely, coconut, eligible, inspiration, labrador,
# Nearest to people: many, china, refuse, planners, reconciled, materialise, pellet, paicv,
# Nearest to will: need, mwi, axial, divorced, symbionts, periodical, charm, vibrant,
# Nearest to b: stood, haldane, kristian, abh, replacement, mausoleum, girard, georg,
# Nearest to road: headline, intergalactic, milder, logging, gerrymandering, veneto, automobile, backwardness,
# Nearest to police: vital, dhabi, fon, interdict, stool, hbt, jupiter, denouncing,
# Nearest to http: www, links, xico, palo, mandrakesoft, myles, noaa, igg,
# Nearest to arts: barry, bayan, event, pedagogue, marrying, cognitively, fairbanks, ovum,
# Nearest to shows: gangster, nader, pickover, bobble, cram, output, sensuous, hyakutake,
# Nearest to engineering: miscarriage, overtime, rhoda, mini, rarely, reviews, hopefully, entertain,
# Nearest to channel: spells, tales, jesuit, coates, shootouts, despise, collusion, nchen,
# Nearest to shown: dora, economists, sanctify, roadways, circulatory, gamespy, bacterial, shehhi,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.3962 0.4200 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.3288 0.4044 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.4234 0.4060 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.3637 0.4004 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.4122 0.4037 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.3904 0.4047 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.3677 0.4079 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.4046 0.4064 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.3597 0.4029 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.3549 0.4021 sec/batch
# Nearest to while: strength, recover, fluorspar, hemorrhage, hunts, forced, petrochemical, evidentiary,
# Nearest to eight: jesse, hindsight, twenty, tre, stumbled, dominique, barton, achaemenid,
# Nearest to other: countries, capillaries, sell, methuen, chopsticks, pulsating, ora, schiff,
# Nearest to these: codify, easterly, gifts, expatriates, muppet, tenn, nodes, fluctuated,
# Nearest to where: cdot, safely, legumes, pavilion, coconut, eligible, metcalfe, inspiration,
# Nearest to people: many, china, living, refuse, materialise, planners, regions, pellet,
# Nearest to will: need, axial, mwi, symbionts, divorced, vibrant, proportionality, rectitude,
# Nearest to b: haldane, stood, girard, kristian, replacement, abh, mausoleum, trucial,
# Nearest to road: headline, intergalactic, gerrymandering, milder, logging, kvar, veneto, extending,
# Nearest to police: vital, interdict, dhabi, killed, tanenbaum, livre, hbt, fon,
# Nearest to http: www, links, palo, xico, mandrakesoft, noaa, myles, sml,
# Nearest to arts: barry, pedagogue, bayan, event, fairbanks, cyanides, cognitively, zenith,
# Nearest to shows: gangster, nader, cram, output, sensuous, pickover, justifiably, thermionic,
# Nearest to engineering: miscarriage, overtime, parliamentarism, reviews, rhoda, hopefully, latterly, rarely,
# Nearest to channel: tales, spells, shootouts, jesuit, coates, collusion, despise, soir,
# Nearest to shown: dora, economists, sanctify, roadways, bacterial, circulatory, apparition, gamespy,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.3650 0.4104 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.3522 0.4047 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.3733 0.4075 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.2662 0.3993 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.3644 0.4037 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.3710 0.4029 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.3278 0.4016 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.2330 0.4036 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.3664 0.4047 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.3473 0.4007 sec/batch
# Nearest to while: strength, recover, fluorspar, hunts, hemorrhage, evidentiary, petrochemical, forced,
# Nearest to eight: twenty, jesse, ton, dominique, hindsight, stumbled, achaemenid, tre,
# Nearest to other: countries, capillaries, sell, schiff, methuen, pulsating, ora, chopsticks,
# Nearest to these: codify, gifts, easterly, muppet, tenn, expatriates, nodes, were,
# Nearest to where: cdot, pavilion, legumes, safely, eligible, coconut, in, metcalfe,
# Nearest to people: many, living, china, refuse, planners, materialise, lives, pellet,
# Nearest to will: axial, need, mwi, symbionts, divorced, proportionality, turtledove, vibrant,
# Nearest to b: haldane, stood, girard, kristian, replacement, abh, trucial, mausoleum,
# Nearest to road: intergalactic, headline, logging, milder, gerrymandering, kvar, extending, backwardness,
# Nearest to police: interdict, vital, dhabi, playmate, killed, opposition, tanenbaum, fon,
# Nearest to http: www, links, xico, palo, mandrakesoft, noaa, org, sml,
# Nearest to arts: barry, pedagogue, fairbanks, bayan, cognitively, cyanides, event, coleridge,
# Nearest to shows: gangster, nader, cram, sensuous, pickover, thermionic, output, justifiably,
# Nearest to engineering: miscarriage, overtime, parliamentarism, hopefully, mini, rhoda, infinitesimally, mitochondria,
# Nearest to channel: spells, shootouts, collusion, tales, jesuit, coates, mt, coining,
# Nearest to shown: dora, economists, roadways, sanctify, circulatory, mechanistic, bacterial, gamespy,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.3567 0.4147 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.3429 0.4051 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.3986 0.4016 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.3307 0.4045 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.2648 0.4053 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.3486 0.4012 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.3491 0.4031 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.3112 0.4051 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.3535 0.4039 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.3205 0.4067 sec/batch
# Nearest to while: strength, hunts, hemorrhage, recover, fluorspar, petrochemical, evidentiary, mascot,
# Nearest to eight: twenty, jesse, rudolph, achaemenid, dominique, ton, tre, hindsight,
# Nearest to other: countries, capillaries, methuen, sell, schiff, pulsating, entities, include,
# Nearest to these: were, codify, gifts, rohmer, muppet, expatriates, celsus, tenn,
# Nearest to where: cdot, pavilion, legumes, safely, coconut, eligible, metcalfe, labrador,
# Nearest to people: many, living, china, lives, planners, refuse, reconciled, materialise,
# Nearest to will: axial, need, mwi, divorced, turtledove, symbionts, rectitude, periodical,
# Nearest to b: haldane, stood, girard, kristian, replacement, streeter, abh, trucial,
# Nearest to road: headline, intergalactic, logging, kvar, milder, gerrymandering, extending, veneto,
# Nearest to police: dhabi, vital, interdict, playmate, killed, fon, hbt, opposing,
# Nearest to http: www, links, xico, mandrakesoft, palo, org, sml, webelements,
# Nearest to arts: barry, pedagogue, fairbanks, bayan, cyanides, event, cognitively, zenith,
# Nearest to shows: gangster, nader, cram, output, sensuous, pickover, thermionic, redshifted,
# Nearest to engineering: miscarriage, overtime, parliamentarism, hopefully, mini, infinitesimally, dissipates, reviews,
# Nearest to channel: shootouts, spells, collusion, coates, jesuit, soir, tales, milestone,
# Nearest to shown: dora, economists, roadways, sanctify, mechanistic, bacterial, apparition, gamespy,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.3323 0.4110 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.3353 0.4023 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.2582 0.4023 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 4.2129 0.4010 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.2682 0.4030 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.2591 0.4035 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.2702 0.4093 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.2238 0.4039 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.3401 0.3881 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.1002 0.4025 sec/batch
# Nearest to while: strength, recover, hunts, chondrite, evidentiary, fluorspar, lillie, hemorrhage,
# Nearest to eight: jesse, dominique, achaemenid, johannes, palamas, rudolph, ton, cinder,
# Nearest to other: countries, capillaries, schiff, sell, include, methuen, pulsating, mpla,
# Nearest to these: were, codify, expatriates, gifts, muppet, tenn, are, rohmer,
# Nearest to where: cdot, pavilion, legumes, safely, coconut, metcalfe, labrador, eligible,
# Nearest to people: living, china, many, lives, planners, materialise, refuse, ud,
# Nearest to will: axial, need, mwi, divorced, polonia, symbionts, naturalization, proportionality,
# Nearest to b: haldane, stood, kristian, girard, mausoleum, replacement, trucial, abh,
# Nearest to road: intergalactic, headline, kvar, logging, gerrymandering, milder, extending, automobile,
# Nearest to police: vital, playmate, dhabi, interdict, denouncing, fon, hbt, auspices,
# Nearest to http: www, links, mandrakesoft, org, xico, noaa, webelements, palo,
# Nearest to arts: barry, pedagogue, bayan, fairbanks, coleridge, simpsons, ultimo, cyanides,
# Nearest to shows: gangster, nader, cram, sensuous, output, thermionic, redshifted, pickover,
# Nearest to engineering: miscarriage, parliamentarism, overtime, hopefully, latterly, mini, mitochondria, reviews,
# Nearest to channel: spells, shootouts, collusion, mt, monoclonal, ramesh, jesuit, milestone,
# Nearest to shown: dora, economists, sanctify, circulatory, roadways, apparition, bacterial, makkah,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 4.1540 0.4096 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 4.1626 0.4038 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 4.2251 0.4032 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 4.2951 0.4040 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 4.2917 0.4040 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 4.2851 0.4016 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 4.3475 0.4008 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 4.3594 0.4037 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 4.3242 0.4023 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 4.2696 0.4042 sec/batch
# Nearest to while: strength, recover, hunts, fluorspar, evidentiary, lillie, hemorrhage, chondrite,
# Nearest to eight: achaemenid, ton, tre, twenty, cinder, danville, palamas, jupiter,
# Nearest to other: countries, capillaries, include, schiff, mpla, starchy, pulsating, methuen,
# Nearest to these: were, codify, are, gifts, specialising, rohmer, tenn, expatriates,
# Nearest to where: cdot, coconut, safely, legumes, pavilion, metcalfe, in, at,
# Nearest to people: living, china, many, lives, planners, reconciled, refuse, materialise,
# Nearest to will: axial, need, symbionts, naturalization, turtledove, divorced, rectitude, mwi,
# Nearest to b: haldane, stood, girard, kristian, replacement, streeter, sporty, slovakian,
# Nearest to road: intergalactic, headline, kvar, logging, gerrymandering, extending, milder, laminate,
# Nearest to police: vital, playmate, denouncing, dhabi, interdict, hbt, killed, opposing,
# Nearest to http: www, links, org, edu, mandrakesoft, html, webelements, noaa,
# Nearest to arts: pedagogue, bayan, fairbanks, barry, cognitively, cyanides, event, garages,
# Nearest to shows: nader, gangster, cram, sensuous, theatrical, pickover, redshifted, output,
# Nearest to engineering: miscarriage, parliamentarism, overtime, latterly, hopefully, baasha, mini, technology,
# Nearest to channel: shootouts, spells, collusion, mt, ramesh, jesuit, monoclonal, soir,
# Nearest to shown: dora, economists, circulatory, makkah, shehhi, sanctify, apparition, roadways,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.1242 0.4113 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 4.2530 0.4071 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 4.2677 0.4023 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 4.2814 0.4031 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 4.2476 0.4035 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 4.3381 0.4076 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.2305 0.4041 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 4.2625 0.4032 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.0256 0.4067 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 4.2202 0.4026 sec/batch
# Nearest to while: strength, recover, fluorspar, evidentiary, forced, chondrite, beas, hunts,
# Nearest to eight: achaemenid, ton, tre, cinder, rudolph, dominique, twenty, ananias,
# Nearest to other: countries, capillaries, schiff, include, mpla, goalposts, any, than,
# Nearest to these: were, codify, specialising, are, nodes, rohmer, tenn, expatriates,
# Nearest to where: cdot, legumes, metcalfe, safely, coconut, pavilion, sdram, pareto,
# Nearest to people: china, living, many, lives, planners, ud, materialise, capone,
# Nearest to will: axial, need, turtledove, naturalization, symbionts, proportionality, rectitude, swap,
# Nearest to b: haldane, stood, girard, kristian, sporty, streeter, slovakian, mausoleum,
# Nearest to road: intergalactic, headline, logging, kvar, extending, gerrymandering, milder, automobile,
# Nearest to police: denouncing, vital, interdict, playmate, dhabi, opposing, killed, auspices,
# Nearest to http: www, links, mandrakesoft, edu, webelements, xico, org, html,
# Nearest to arts: barry, pedagogue, bayan, summarizing, fairbanks, cognitively, cyanides, biafra,
# Nearest to shows: nader, gangster, cram, sensuous, theatrical, upcoming, redshifted, pickover,
# Nearest to engineering: miscarriage, parliamentarism, overtime, technology, baasha, pioneering, hopefully, latterly,
# Nearest to channel: spells, shootouts, mt, collusion, coates, jesuit, monoclonal, ramesh,
# Nearest to shown: dora, makkah, shehhi, economists, xf, connectives, module, circulatory,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 4.2651 0.4109 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 4.1208 0.4019 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 4.2147 0.4023 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 4.2455 0.4039 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 4.2458 0.4031 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 4.2180 0.4037 sec/batch
# Epoch 1/10 Iteration: 11700 Avg. Training loss: 4.2653 0.4015 sec/batch
# Epoch 1/10 Iteration: 11800 Avg. Training loss: 4.2308 0.4054 sec/batch
# Epoch 1/10 Iteration: 11900 Avg. Training loss: 4.2978 0.4025 sec/batch
# Epoch 2/10 Iteration: 12000 Avg. Training loss: 4.2555 0.3346 sec/batch
# Nearest to while: strength, evidentiary, recover, fluorspar, lillie, hunts, widows, forced,
# Nearest to eight: achaemenid, jul, tre, ton, rudolph, jupiter, dominique, stumbled,
# Nearest to other: countries, capillaries, include, schiff, hand, mpla, any, than,
# Nearest to these: were, codify, are, gifts, nodes, specialising, tenn, expatriates,
# Nearest to where: cdot, metcalfe, legumes, coconut, safely, pavilion, sdram, mornay,
# Nearest to people: living, china, many, lives, refuse, planners, imagined, ud,
# Nearest to will: axial, turtledove, naturalization, need, swap, rectitude, symbionts, microcode,
# Nearest to b: haldane, stood, girard, kristian, slovakian, sporty, streeter, catullus,
# Nearest to road: intergalactic, headline, kvar, logging, extending, milder, gerrymandering, laminate,
# Nearest to police: denouncing, playmate, vital, dhabi, interdict, officer, killed, opposing,
# Nearest to http: www, links, edu, webelements, org, mandrakesoft, html, noaa,
# Nearest to arts: pedagogue, barry, fairbanks, bayan, cognitively, biafra, cyanides, summarizing,
# Nearest to shows: gangster, nader, cram, theatrical, sensuous, upcoming, pickover, pris,
# Nearest to engineering: miscarriage, overtime, pioneering, technology, molybdenum, parliamentarism, mitochondria, peer,
# Nearest to channel: shootouts, spells, collusion, mt, coates, jesuit, ramesh, soir,
# Nearest to shown: dora, shehhi, xf, roadways, connectives, sanctify, circulatory, bulwark,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.1913 0.4105 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.2191 0.4037 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.2104 0.4016 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.1606 0.4063 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.2131 0.4051 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.1426 0.4053 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.1372 0.4043 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 4.1962 0.4040 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 4.1920 0.4047 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.1843 0.4013 sec/batch
# Nearest to while: strength, fluorspar, ambrosians, recover, evidentiary, widows, lillie, bocks,
# Nearest to eight: tre, achaemenid, jul, dominique, ns, ton, mathias, ananias,
# Nearest to other: countries, capillaries, include, schiff, mpla, hand, methuen, any,
# Nearest to these: were, are, codify, gifts, rohmer, nodes, agnostics, paisiello,
# Nearest to where: cdot, metcalfe, legumes, coconut, pavilion, safely, sdram, drifted,
# Nearest to people: living, china, lives, many, planners, capone, reconciled, imagined,
# Nearest to will: turtledove, axial, naturalization, need, swap, symbionts, divorced, microcode,
# Nearest to b: haldane, stood, slovakian, kristian, girard, sporty, streeter, catullus,
# Nearest to road: intergalactic, headline, kvar, logging, extending, milder, automobile, gerrymandering,
# Nearest to police: denouncing, vital, officer, interdict, playmate, killed, dhabi, opposing,
# Nearest to http: www, links, edu, webelements, html, org, mandrakesoft, xico,
# Nearest to arts: cognitively, bayan, barry, fairbanks, styles, pedagogue, summarizing, cyanides,
# Nearest to shows: gangster, nader, sensuous, cram, upcoming, redshifted, output, cabinda,
# Nearest to engineering: miscarriage, overtime, pioneering, parliamentarism, molybdenum, baasha, latterly, technology,
# Nearest to channel: shootouts, coates, collusion, spells, mt, jesuit, ramesh, soir,
# Nearest to shown: dora, shehhi, sanctify, circulatory, connectives, apparition, roadways, xf,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.1744 0.4114 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.2491 0.4053 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.1763 0.4057 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.1955 0.4032 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.1956 0.4029 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.1747 0.4028 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.0571 0.4026 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.2052 0.4039 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.2330 0.4039 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.1910 0.4039 sec/batch
# Nearest to while: strength, ambrosians, evidentiary, fluorspar, bocks, lillie, recover, widows,
# Nearest to eight: achaemenid, jul, ananias, ns, dominique, tre, ton, mathias,
# Nearest to other: countries, capillaries, include, hand, goalposts, any, mpla, than,
# Nearest to these: were, are, codify, rohmer, nodes, expatriates, paisiello, misc,
# Nearest to where: cdot, metcalfe, safely, legumes, coconut, pavilion, drifted, prevenient,
# Nearest to people: living, china, lives, many, capone, garter, ud, creoles,
# Nearest to will: axial, naturalization, turtledove, swap, symbionts, need, microcode, proportionality,
# Nearest to b: haldane, stood, slovakian, girard, sporty, streeter, catullus, arbitral,
# Nearest to road: intergalactic, logging, headline, kvar, extending, milder, automobile, laminate,
# Nearest to police: vital, interdict, officer, denouncing, playmate, dhabi, killed, auspices,
# Nearest to http: www, org, html, webelements, edu, links, mandrakesoft, noaa,
# Nearest to arts: cognitively, styles, bayan, academy, barry, art, pedagogue, cyanides,
# Nearest to shows: gangster, nader, cram, sensuous, upcoming, theatrical, output, leninism,
# Nearest to engineering: miscarriage, overtime, pioneering, parliamentarism, molybdenum, baasha, peer, technology,
# Nearest to channel: shootouts, coates, mt, jesuit, collusion, spells, radio, soir,
# Nearest to shown: dora, shehhi, sanctify, roadways, circulatory, connectives, apparition, xf,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.1809 0.4155 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.2000 0.4047 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.1841 0.4019 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.1972 0.4039 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.2138 0.4018 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.1498 0.4048 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.1562 0.4057 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.0821 0.4009 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.0504 0.4005 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.1714 0.4019 sec/batch
# Nearest to while: strength, evidentiary, fluorspar, ambrosians, bocks, expositor, recover, hunts,
# Nearest to eight: ananias, achaemenid, ton, ns, jul, cinder, twenty, mathias,
# Nearest to other: countries, capillaries, include, hand, any, goalposts, than, schiff,
# Nearest to these: were, are, nodes, expatriates, specialising, codify, gifts, paisiello,
# Nearest to where: cdot, metcalfe, safely, coconut, legumes, pavilion, azrael, prevenient,
# Nearest to people: living, china, lives, many, capone, creoles, planners, ud,
# Nearest to will: naturalization, axial, turtledove, swap, symbionts, need, proportionality, rectitude,
# Nearest to b: haldane, stood, slovakian, sporty, girard, streeter, catullus, arbitral,
# Nearest to road: intergalactic, headline, kvar, logging, extending, milder, automobile, laminate,
# Nearest to police: officer, vital, interdict, playmate, dhabi, denouncing, killed, crime,
# Nearest to http: www, html, webelements, org, edu, links, com, xico,
# Nearest to arts: academy, styles, cognitively, bayan, barry, art, tech, fine,
# Nearest to shows: gangster, cram, nader, sensuous, upcoming, cabinda, output, theatrical,
# Nearest to engineering: miscarriage, pioneering, overtime, parliamentarism, technology, latterly, molybdenum, graduate,
# Nearest to channel: shootouts, coates, jesuit, radio, collusion, mt, soir, ramesh,
# Nearest to shown: dora, apparition, roadways, shehhi, oboe, sanctify, connectives, federals,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.1372 0.4132 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.1383 0.4016 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.1506 0.4014 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.1649 0.4047 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.0568 0.4038 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.1871 0.4028 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.1858 0.4020 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.1599 0.4042 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.1697 0.4043 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.1490 0.4029 sec/batch
# Nearest to while: evidentiary, strength, fluorspar, bocks, ambrosians, recover, hunts, expositor,
# Nearest to eight: achaemenid, ton, ananias, tre, danville, jupiter, twenty, palamas,
# Nearest to other: countries, hand, capillaries, include, any, than, mpla, goalposts,
# Nearest to these: were, are, nodes, specialising, gifts, codify, rohmer, none,
# Nearest to where: cdot, legumes, metcalfe, coconut, safely, azrael, pareto, pavilion,
# Nearest to people: living, china, lives, many, planners, creoles, capone, garter,
# Nearest to will: axial, turtledove, naturalization, need, swap, symbionts, rectitude, microcode,
# Nearest to b: haldane, stood, slovakian, streeter, girard, sporty, arbitral, accumulating,
# Nearest to road: intergalactic, kvar, headline, logging, veneto, stormont, milder, extending,
# Nearest to police: officer, vital, crime, playmate, interdict, killed, denouncing, dhabi,
# Nearest to http: www, html, org, webelements, edu, links, com, mandrakesoft,
# Nearest to arts: academy, art, tech, bayan, fairbanks, barry, fine, summarizing,
# Nearest to shows: gangster, cram, nader, upcoming, sensuous, cabinda, showing, theatrical,
# Nearest to engineering: miscarriage, graduate, pioneering, overtime, parliamentarism, technology, peer, institutes,
# Nearest to channel: shootouts, radio, coates, mt, collusion, spells, jesuit, broadcasting,
# Nearest to shown: apparition, dora, shehhi, circulatory, roadways, sanctify, federals, connectives,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.1596 0.4127 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.2250 0.4047 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.1055 0.4029 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.1598 0.4010 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.1130 0.3997 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.1726 0.4007 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.1704 0.4035 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.2015 0.4046 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.1700 0.4068 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 4.1655 0.4048 sec/batch
# Nearest to while: strength, evidentiary, ambrosians, fluorspar, bocks, expositor, recover, lillie,
# Nearest to eight: achaemenid, tre, dominique, cinder, ton, palamas, ns, danville,
# Nearest to other: countries, hand, capillaries, any, include, goalposts, mpla, than,
# Nearest to these: were, are, none, gifts, specialising, codify, nodes, rohmer,
# Nearest to where: cdot, legumes, coconut, safely, metcalfe, pareto, azrael, fanpage,
# Nearest to people: living, china, lives, garter, many, capone, planners, creoles,
# Nearest to will: axial, naturalization, turtledove, need, swap, rectitude, symbionts, minestrone,
# Nearest to b: haldane, stood, slovakian, kristian, sporty, girard, arbitral, streeter,
# Nearest to road: intergalactic, headline, logging, kvar, automobile, stormont, veneto, milder,
# Nearest to police: officer, killed, crime, vital, playmate, interdict, denouncing, magma,
# Nearest to http: www, edu, webelements, html, org, links, htm, mandrakesoft,
# Nearest to arts: academy, fairbanks, fine, bayan, art, cognitively, barry, garages,
# Nearest to shows: gangster, cram, nader, upcoming, cabinda, showing, theatrical, output,
# Nearest to engineering: miscarriage, pioneering, overtime, technology, parliamentarism, graduate, recreation, peer,
# Nearest to channel: shootouts, coates, spells, radio, collusion, mt, jesuit, soir,
# Nearest to shown: dora, apparition, roadways, oboe, circulatory, shehhi, federals, xf,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.0885 0.4107 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.1644 0.4043 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.0682 0.4025 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.1635 0.4016 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.1623 0.4056 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.1240 0.4090 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 4.1793 0.4049 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 4.1554 0.4002 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.0889 0.4044 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 4.1408 0.4028 sec/batch
# Nearest to while: evidentiary, ambrosians, strength, bocks, fluorspar, expositor, recover, hunts,
# Nearest to eight: achaemenid, dominique, cinder, danville, gwh, tre, ananias, barton,
# Nearest to other: hand, countries, capillaries, any, include, than, schiff, starchy,
# Nearest to these: were, are, none, correcting, nodes, paisiello, tenn, expatriates,
# Nearest to where: cdot, coconut, safely, he, naumburg, pareto, picturesque, metcalfe,
# Nearest to people: living, china, lives, garter, creoles, capone, many, planners,
# Nearest to will: axial, naturalization, turtledove, minestrone, rectitude, proportionality, swap, materialize,
# Nearest to b: haldane, stood, slovakian, kristian, sporty, streeter, subfamilia, girard,
# Nearest to road: intergalactic, kvar, logging, headline, automobile, stormont, milder, miami,
# Nearest to police: killed, officer, vital, crime, interdict, denouncing, playmate, kirov,
# Nearest to http: www, edu, html, webelements, org, htm, links, xico,
# Nearest to arts: academy, fine, art, bayan, cognitively, styles, fairbanks, garages,
# Nearest to shows: gangster, upcoming, cram, nader, showing, output, cabinda, redshifted,
# Nearest to engineering: miscarriage, pioneering, parliamentarism, overtime, technology, recreation, peer, vdp,
# Nearest to channel: shootouts, coates, jesuit, spells, soir, radio, mt, broadcasting,
# Nearest to shown: dora, bacterial, oboe, roadways, apparition, circulatory, connectives, federals,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.0992 0.4149 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.1768 0.4023 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 4.0164 0.4034 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.1412 0.4048 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.1712 0.4032 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 4.1162 0.4019 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 4.0367 0.4065 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 4.1477 0.4040 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 4.1476 0.4023 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 4.1364 0.4029 sec/batch
# Nearest to while: evidentiary, bocks, strength, ambrosians, expositor, fluorspar, recover, hunts,
# Nearest to eight: achaemenid, dominique, mathias, cinder, danville, ananias, ns, gwh,
# Nearest to other: hand, countries, capillaries, than, any, include, mpla, schiff,
# Nearest to these: were, are, none, gifts, codify, nodes, celsus, correcting,
# Nearest to where: cdot, he, safely, coconut, naumburg, pareto, picturesque, metcalfe,
# Nearest to people: living, china, lives, garter, planners, creoles, capone, killing,
# Nearest to will: axial, naturalization, turtledove, rectitude, minestrone, proportionality, cultured, swap,
# Nearest to b: haldane, slovakian, stood, girard, sporty, streeter, kristian, arbitral,
# Nearest to road: intergalactic, kvar, logging, headline, milder, stormont, automobile, laminate,
# Nearest to police: officer, killed, crime, vital, interdict, personnel, auspices, denouncing,
# Nearest to http: www, edu, html, webelements, org, htm, com, links,
# Nearest to arts: academy, art, fine, cognitively, bayan, fairbanks, garages, duvalier,
# Nearest to shows: gangster, upcoming, cram, nader, showing, cabinda, output, leninism,
# Nearest to engineering: miscarriage, overtime, pioneering, parliamentarism, vdp, infinitesimally, technology, technologies,
# Nearest to channel: shootouts, coates, mt, radio, jesuit, broadcasting, spells, ramesh,
# Nearest to shown: dora, bacterial, apparition, roadways, federals, circulatory, oboe, connectives,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 4.1634 0.4111 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 4.1877 0.4043 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 4.1331 0.4065 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 4.0729 0.4057 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 4.1888 0.4064 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 4.1567 0.4042 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 4.1352 0.4005 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 4.1682 0.4056 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 4.1546 0.4034 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 4.1489 0.3999 sec/batch
# Nearest to while: evidentiary, bocks, strength, widows, ambrosians, expositor, fluorspar, beas,
# Nearest to eight: achaemenid, mathias, danville, dominique, reconquered, cinder, sofie, ns,
# Nearest to other: hand, countries, capillaries, any, than, include, goalposts, schiff,
# Nearest to these: were, are, none, specialising, codify, gifts, misc, tenn,
# Nearest to where: cdot, coconut, naumburg, he, safely, picturesque, jigger, partners,
# Nearest to people: living, china, lives, many, planners, creoles, garter, killing,
# Nearest to will: axial, turtledove, naturalization, rectitude, materialize, cultured, minestrone, divorced,
# Nearest to b: haldane, slovakian, stood, sporty, streeter, catullus, girard, arbitral,
# Nearest to road: intergalactic, kvar, logging, headline, milder, automobile, stormont, payloads,
# Nearest to police: killed, crime, officer, auspices, playmate, vital, interdict, kirov,
# Nearest to http: www, edu, html, webelements, org, xico, mandrakesoft, noaa,
# Nearest to arts: art, academy, fine, cognitively, fairbanks, duvalier, garages, performing,
# Nearest to shows: gangster, upcoming, nader, cram, showing, cabinda, output, theatrical,
# Nearest to engineering: miscarriage, pioneering, overtime, parliamentarism, infinitesimally, technology, vdp, baasha,
# Nearest to channel: shootouts, mt, coates, broadcasting, jesuit, radio, spells, collusion,
# Nearest to shown: dora, apparition, roadways, federals, bacterial, xf, oboe, circulatory,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 4.1695 0.4123 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 4.1135 0.4006 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 4.0337 0.4046 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 4.1029 0.4071 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 4.1032 0.4008 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 4.1311 0.4058 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 4.0791 0.4004 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 4.1992 0.4021 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 3.9758 0.4019 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 3.9686 0.4029 sec/batch
# Nearest to while: evidentiary, bocks, lillie, others, friedman, regis, rajkumar, ambrosians,
# Nearest to eight: dominique, achaemenid, mathias, barton, yvette, cinder, ns, sofie,
# Nearest to other: hand, countries, capillaries, any, than, include, goalposts, schiff,
# Nearest to these: were, are, none, expatriates, misc, rohmer, codify, tenn,
# Nearest to where: cdot, he, naumburg, coconut, jigger, picturesque, metcalfe, ucd,
# Nearest to people: living, china, lives, garter, killing, planners, many, creoles,
# Nearest to will: naturalization, turtledove, axial, materialize, rectitude, cultured, swap, divorced,
# Nearest to b: haldane, slovakian, kristian, stood, sporty, girard, catullus, ceau,
# Nearest to road: intergalactic, kvar, headline, logging, automobile, laminate, backwaters, stormont,
# Nearest to police: killed, officer, crime, vital, personnel, auspices, follette, playmate,
# Nearest to http: www, edu, html, webelements, noaa, mandrakesoft, xico, htm,
# Nearest to arts: art, academy, fine, fairbanks, duvalier, garages, styles, summarizing,
# Nearest to shows: gangster, upcoming, cram, showing, nader, cabinda, pris, fraternal,
# Nearest to engineering: miscarriage, pioneering, overtime, technology, parliamentarism, technologies, infinitesimally, vdp,
# Nearest to channel: shootouts, spells, mt, jesuit, broadcasting, sault, coates, auxiliary,
# Nearest to shown: dora, federals, apparition, oboe, bacterial, roadways, jurchen, xf,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 4.0049 0.4114 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 4.0703 0.4049 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 4.1252 0.4059 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 4.1722 0.4026 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 4.1361 0.4001 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 4.1981 0.3860 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 4.2104 0.4043 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 4.2003 0.4022 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 4.1291 0.4044 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 3.9983 0.4035 sec/batch
# Nearest to while: evidentiary, bocks, strength, others, widows, fluorspar, friedman, ambrosians,
# Nearest to eight: achaemenid, gwh, ton, cinder, ananias, danville, fam, barton,
# Nearest to other: hand, countries, capillaries, than, include, any, each, uses,
# Nearest to these: were, are, none, expatriates, codify, misc, specialising, rohmer,
# Nearest to where: cdot, naumburg, coconut, safely, picturesque, he, metcalfe, jigger,
# Nearest to people: living, china, lives, planners, garter, creoles, killing, many,
# Nearest to will: naturalization, axial, turtledove, rectitude, materialize, cultured, proportionality, minestrone,
# Nearest to b: haldane, slovakian, stood, sporty, catullus, streeter, kristian, girard,
# Nearest to road: intergalactic, logging, kvar, headline, roads, laminate, backwaters, stormont,
# Nearest to police: killed, officer, crime, personnel, playmate, vital, auspices, denouncing,
# Nearest to http: www, edu, html, webelements, xico, noaa, mandrakesoft, org,
# Nearest to arts: art, academy, fine, styles, garages, duvalier, bayan, performing,
# Nearest to shows: gangster, upcoming, showing, nader, cram, cabinda, theatrical, fraternal,
# Nearest to engineering: miscarriage, pioneering, technology, parliamentarism, overtime, technologies, baasha, rhoda,
# Nearest to channel: shootouts, mt, spells, broadcasting, jesuit, sault, soir, coates,
# Nearest to shown: apparition, federals, dora, oboe, jurchen, bacterial, asterion, credited,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 4.1262 0.4172 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 4.1383 0.4006 sec/batch
# Epoch 2/10 Iteration: 22300 Avg. Training loss: 4.0884 0.4029 sec/batch
# Epoch 2/10 Iteration: 22400 Avg. Training loss: 4.1209 0.4036 sec/batch
# Epoch 2/10 Iteration: 22500 Avg. Training loss: 4.1702 0.4038 sec/batch
# ...
# Nearest to other: hand, each, disambiguation, uses, any, than, redirects, unlike,
# Nearest to these: include, none, were, are, included, enslavable, barker, brackish,
# Nearest to where: situations, moved, cases, meets, place, he, places, boldsymbol,
# Nearest to people: living, republic, china, births, kills, ordinary, killing, killed,
# Nearest to will: continue, tend, likely, eventually, leprechaun, remain, turtledove, be,
# Nearest to b: gorden, leader, glides, sushi, c, aden, catullus, slovakian,
# Nearest to road: roads, silk, toll, traffic, stormont, safety, nearest, route,
# Nearest to police: driving, officer, mla, officers, trouble, crime, thugs, department,
# Nearest to http: www, htm, org, edu, html, com, index, xico,
# Nearest to arts: fine, performing, art, kung, academy, joint, silver, appliqu,
# Nearest to shows: showing, show, states, illustrates, that, genovese, swung, hissarlik,
# Nearest to engineering: engineers, engineer, miscarriage, doubtless, technologies, wurzel, struggled, eth,
# Nearest to channel: auxiliary, biased, raleigh, wb, piovra, channels, nucellus, abiogenesis,
# Nearest to shown: studies, been, exposures, cinemas, below, pharmacokinetics, credited, introducing,
# Epoch 10/10 Iteration: 112100 Avg. Training loss: 4.0088 0.4120 sec/batch
# Epoch 10/10 Iteration: 112200 Avg. Training loss: 4.0150 0.4057 sec/batch
# Epoch 10/10 Iteration: 112300 Avg. Training loss: 3.9955 0.4054 sec/batch
# Epoch 10/10 Iteration: 112400 Avg. Training loss: 3.9604 0.4041 sec/batch
# Epoch 10/10 Iteration: 112500 Avg. Training loss: 3.9014 0.4041 sec/batch
# Epoch 10/10 Iteration: 112600 Avg. Training loss: 3.9303 0.4097 sec/batch
# Epoch 10/10 Iteration: 112700 Avg. Training loss: 3.9783 0.4044 sec/batch
# Epoch 10/10 Iteration: 112800 Avg. Training loss: 4.0049 0.4047 sec/batch
# Epoch 10/10 Iteration: 112900 Avg. Training loss: 3.9667 0.4044 sec/batch
# Epoch 10/10 Iteration: 113000 Avg. Training loss: 3.9826 0.4082 sec/batch
# Nearest to while: others, still, maintaining, retaining, attempting, balkanization, trying, yearwood,
# Nearest to eight: nine, one, six, seven, abbott, verus, five, four,
# Nearest to other: hand, each, disambiguation, uses, any, than, unlike, meanings,
# Nearest to these: include, none, were, are, enslavable, included, brackish, barker,
# Nearest to where: situations, moved, he, place, meets, cases, places, ge,
# Nearest to people: living, republic, china, kills, births, killed, ordinary, killing,
# Nearest to will: continue, likely, tend, eventually, remain, turtledove, expected, minestrone,
# Nearest to b: c, glides, hom, gorden, aden, schema, sushi, flatulence,
# Nearest to road: roads, silk, stormont, safety, nearest, wont, wainwright, pauli,
# Nearest to police: driving, officer, officers, mla, follette, robot, thugs, magma,
# Nearest to http: www, htm, html, org, edu, com, index, xico,
# Nearest to arts: fine, performing, art, kung, academy, silver, joint, garages,
# Nearest to shows: showing, show, states, illustrates, that, swung, monomyth, larwood,
# Nearest to engineering: engineers, engineer, miscarriage, doubtless, technologies, technical, wurzel, centimeter,
# Nearest to channel: auxiliary, biased, raleigh, piovra, channels, wb, nucellus, calais,
# Nearest to shown: studies, cinemas, below, exposures, asterion, seen, introducing, pharmacokinetics,
# Epoch 10/10 Iteration: 113100 Avg. Training loss: 3.9826 0.4141 sec/batch
# Epoch 10/10 Iteration: 113200 Avg. Training loss: 3.9163 0.4057 sec/batch
# Epoch 10/10 Iteration: 113300 Avg. Training loss: 3.9665 0.4060 sec/batch
# Epoch 10/10 Iteration: 113400 Avg. Training loss: 3.9337 0.4053 sec/batch
# Epoch 10/10 Iteration: 113500 Avg. Training loss: 3.9984 0.4059 sec/batch
# Epoch 10/10 Iteration: 113600 Avg. Training loss: 3.8275 0.4046 sec/batch
# Epoch 10/10 Iteration: 113700 Avg. Training loss: 3.9992 0.4064 sec/batch
# Epoch 10/10 Iteration: 113800 Avg. Training loss: 3.9988 0.4072 sec/batch
# Epoch 10/10 Iteration: 113900 Avg. Training loss: 3.9523 0.4050 sec/batch
# Epoch 10/10 Iteration: 114000 Avg. Training loss: 3.9468 0.4048 sec/batch
# Nearest to while: others, still, maintaining, retaining, attempting, trying, balkanization, holding,
# Nearest to eight: nine, one, six, seven, four, lightning, five, ezo,
# Nearest to other: hand, each, disambiguation, uses, any, than, meanings, unlike,
# Nearest to these: include, none, were, are, included, enslavable, barker, brackish,
# Nearest to where: situations, place, moved, meets, cases, he, places, ge,
# Nearest to people: living, republic, china, ordinary, births, kills, hakka, killed,
# Nearest to will: continue, tend, likely, eventually, turtledove, remain, minestrone, expected,
# Nearest to b: glides, mausoleum, gorden, leader, c, flatulence, schema, aden,
# Nearest to road: roads, silk, stormont, nearest, wont, toll, traffic, saban,
# Nearest to police: officer, driving, officers, guard, mla, fire, battalion, military,
# Nearest to http: www, htm, org, html, edu, com, index, xico,
# Nearest to arts: fine, performing, art, kung, silver, academy, garages, appliqu,
# Nearest to shows: showing, show, states, illustrates, swung, periodicity, genovese, filking,
# Nearest to engineering: engineer, engineers, miscarriage, doubtless, wurzel, technologies, eth, centimeter,
# Nearest to channel: auxiliary, biased, raleigh, channels, piovra, wb, calais, soir,
# Nearest to shown: studies, cinemas, below, exposures, seen, pharmacokinetics, introducing, asterion,
# Epoch 10/10 Iteration: 114100 Avg. Training loss: 3.9060 0.4137 sec/batch
# Epoch 10/10 Iteration: 114200 Avg. Training loss: 3.9947 0.4029 sec/batch
# Epoch 10/10 Iteration: 114300 Avg. Training loss: 3.9922 0.4052 sec/batch
# Epoch 10/10 Iteration: 114400 Avg. Training loss: 3.9994 0.4042 sec/batch
# Epoch 10/10 Iteration: 114500 Avg. Training loss: 4.0157 0.4023 sec/batch
# Epoch 10/10 Iteration: 114600 Avg. Training loss: 4.0151 0.4057 sec/batch
# Epoch 10/10 Iteration: 114700 Avg. Training loss: 3.8948 0.4047 sec/batch
# Epoch 10/10 Iteration: 114800 Avg. Training loss: 3.9967 0.4051 sec/batch
# Epoch 10/10 Iteration: 114900 Avg. Training loss: 3.9988 0.4053 sec/batch
# Epoch 10/10 Iteration: 115000 Avg. Training loss: 4.0070 0.4050 sec/batch
# Nearest to while: others, still, maintaining, retaining, attempting, working, balkanization, trying,
# Nearest to eight: nine, one, six, seven, four, vuk, lightning, founded,
# Nearest to other: hand, each, disambiguation, uses, any, meanings, than, unlike,
# Nearest to these: include, none, were, are, enslavable, barker, included, brackish,
# Nearest to where: situations, place, moved, meets, cases, he, places, boldsymbol,
# Nearest to people: living, republic, china, ordinary, killed, births, kills, killing,
# Nearest to will: likely, continue, tend, minestrone, remain, be, expected, turtledove,
# Nearest to b: glides, c, mausoleum, flatulence, hom, gorden, slovakian, occasioned,
# Nearest to road: roads, silk, wont, stormont, traffic, nearest, street, toll,
# Nearest to police: officer, driving, officers, battalion, robot, thugs, mla, subnational,
# Nearest to http: www, html, htm, org, edu, com, index, xico,
# Nearest to arts: fine, performing, art, kung, academy, joint, silver, garages,
# Nearest to shows: showing, show, states, illustrates, vicuna, filking, genovese, larwood,
# Nearest to engineering: engineers, engineer, miscarriage, doubtless, wurzel, technologies, eth, weiss,
# Nearest to channel: auxiliary, biased, raleigh, piovra, channels, wb, soir, calais,
# Nearest to shown: studies, below, cinemas, asterion, exposures, austroasiatic, pharmacokinetics, displayed,
# Epoch 10/10 Iteration: 115100 Avg. Training loss: 3.9624 0.4141 sec/batch
# Epoch 10/10 Iteration: 115200 Avg. Training loss: 4.0065 0.4034 sec/batch
# Epoch 10/10 Iteration: 115300 Avg. Training loss: 3.9819 0.4068 sec/batch
# Epoch 10/10 Iteration: 115400 Avg. Training loss: 4.0068 0.4054 sec/batch
# Epoch 10/10 Iteration: 115500 Avg. Training loss: 3.9661 0.4131 sec/batch
# Epoch 10/10 Iteration: 115600 Avg. Training loss: 3.8804 0.4070 sec/batch
# Epoch 10/10 Iteration: 115700 Avg. Training loss: 3.9505 0.4041 sec/batch
# Epoch 10/10 Iteration: 115800 Avg. Training loss: 3.9482 0.4037 sec/batch
# Epoch 10/10 Iteration: 115900 Avg. Training loss: 3.9717 0.4031 sec/batch
# Epoch 10/10 Iteration: 116000 Avg. Training loss: 3.9510 0.4054 sec/batch
# Nearest to while: others, still, maintaining, retaining, working, attempting, balkanization, trying,
# Nearest to eight: nine, one, six, four, seven, three, five, beagle,
# Nearest to other: hand, each, disambiguation, uses, any, meanings, than, unlike,
# Nearest to these: include, none, are, were, included, enslavable, respectively, brackish,
# Nearest to where: situations, place, cases, meets, places, moved, boldsymbol, he,
# Nearest to people: living, republic, china, ordinary, killed, kills, hakka, killing,
# Nearest to will: likely, continue, tend, expected, be, minestrone, next, eventually,
# Nearest to b: c, glides, organelle, flatulence, f, mausoleum, aden, powerplants,
# Nearest to road: roads, silk, stormont, toll, traffic, wont, nearest, route,
# Nearest to police: driving, officer, officers, military, fire, battalion, department, subnational,
# Nearest to http: www, htm, org, html, edu, com, index, xico,
# Nearest to arts: fine, performing, art, kung, academy, silver, joint, appliqu,
# Nearest to shows: showing, show, states, vicuna, illustrates, filking, suggests, occitan,
# Nearest to engineering: engineers, engineer, miscarriage, technologies, doubtless, wurzel, eth, technical,
# Nearest to channel: auxiliary, biased, raleigh, channels, wb, piovra, nucellus, neutralist,
# Nearest to shown: studies, below, cinemas, been, exposures, pharmacokinetics, asterion, displayed,
# Epoch 10/10 Iteration: 116100 Avg. Training loss: 3.9769 0.4157 sec/batch
# Epoch 10/10 Iteration: 116200 Avg. Training loss: 3.9739 0.4045 sec/batch
# Epoch 10/10 Iteration: 116300 Avg. Training loss: 3.6938 0.4058 sec/batch
# Epoch 10/10 Iteration: 116400 Avg. Training loss: 3.8538 0.4063 sec/batch
# Epoch 10/10 Iteration: 116500 Avg. Training loss: 3.8753 0.4091 sec/batch
# Epoch 10/10 Iteration: 116600 Avg. Training loss: 3.9637 0.4105 sec/batch
# Epoch 10/10 Iteration: 116700 Avg. Training loss: 4.0141 0.4056 sec/batch
# Epoch 10/10 Iteration: 116800 Avg. Training loss: 4.0066 0.4051 sec/batch
# Epoch 10/10 Iteration: 116900 Avg. Training loss: 4.0324 0.4039 sec/batch
# Epoch 10/10 Iteration: 117000 Avg. Training loss: 4.0555 0.4085 sec/batch
# Nearest to while: others, maintaining, still, retaining, working, trying, attempting, balkanization,
# Nearest to eight: nine, one, hackett, modes, lightning, six, beagle, seven,
# Nearest to other: hand, each, disambiguation, uses, any, meanings, unlike, than,
# Nearest to these: include, none, were, are, included, enslavable, barker, fingerspelling,
# Nearest to where: moved, he, situations, meets, place, cases, places, amphitryon,
# Nearest to people: living, republic, china, ordinary, births, kills, killing, directors,
# Nearest to will: continue, tend, likely, happen, expected, minestrone, turtledove, remain,
# Nearest to b: glides, gorden, sushi, sporty, leader, marched, slovakian, mausoleum,
# Nearest to road: roads, silk, toll, stormont, wont, ono, nearest, bites,
# Nearest to police: officer, driving, officers, department, fire, battalion, mla, guard,
# Nearest to http: www, htm, org, edu, html, com, xico, index,
# Nearest to arts: fine, performing, kung, martial, art, combat, academy, silver,
# Nearest to shows: showing, show, states, vicuna, swung, occitan, hissarlik, illustrates,
# Nearest to engineering: engineer, engineers, miscarriage, technologies, eth, doubtless, wurzel, centimeter,
# Nearest to channel: auxiliary, biased, raleigh, channels, piovra, wb, calais, neutralist,
# Nearest to shown: studies, cinemas, below, asterion, filmed, displayed, seen, introducing,
# Epoch 10/10 Iteration: 117100 Avg. Training loss: 4.0508 0.4132 sec/batch
# Epoch 10/10 Iteration: 117200 Avg. Training loss: 3.9971 0.3759 sec/batch
# Epoch 10/10 Iteration: 117300 Avg. Training loss: 3.9415 0.3820 sec/batch
# Epoch 10/10 Iteration: 117400 Avg. Training loss: 3.8838 0.4052 sec/batch
# Epoch 10/10 Iteration: 117500 Avg. Training loss: 3.9583 0.4064 sec/batch
# Epoch 10/10 Iteration: 117600 Avg. Training loss: 3.9178 0.4039 sec/batch
# Epoch 10/10 Iteration: 117700 Avg. Training loss: 4.0039 0.4055 sec/batch
# Epoch 10/10 Iteration: 117800 Avg. Training loss: 3.9256 0.4040 sec/batch
# Epoch 10/10 Iteration: 117900 Avg. Training loss: 4.0128 0.4059 sec/batch
# Epoch 10/10 Iteration: 118000 Avg. Training loss: 3.9401 0.4028 sec/batch
# Nearest to while: others, still, maintaining, retaining, working, trying, balkanization, attempting,
# Nearest to eight: nine, one, seven, six, four, three, two, five,
# Nearest to other: hand, each, disambiguation, uses, any, meanings, than, unlike,
# Nearest to these: include, none, are, were, included, enslavable, fingerspelling, respectively,
# Nearest to where: situations, cases, he, moved, meets, place, places, boldsymbol,
# Nearest to people: living, china, republic, ordinary, births, kills, killing, hakka,
# Nearest to will: continue, tend, likely, remain, expected, minestrone, eventually, turtledove,
# Nearest to b: glides, c, sushi, occasioned, gorden, flatulence, marched, slovakian,
# Nearest to road: roads, silk, toll, wont, stormont, safety, wainwright, saban,
# Nearest to police: officer, driving, department, officers, fire, mla, magma, robot,
# Nearest to http: www, htm, org, html, edu, com, xico, index,
# Nearest to arts: fine, performing, kung, art, academy, martial, liberal, combat,
# Nearest to shows: showing, show, states, swung, vicuna, illustrates, displaying, kary,
# Nearest to engineering: engineers, engineer, technologies, miscarriage, science, doubtless, technical, wurzel,
# Nearest to channel: auxiliary, biased, raleigh, channels, piovra, wb, halfway, calais,
# Nearest to shown: studies, below, asterion, been, filmed, introducing, seen, cinemas,
# Epoch 10/10 Iteration: 118100 Avg. Training loss: 3.8575 0.4147 sec/batch
# Epoch 10/10 Iteration: 118200 Avg. Training loss: 3.7995 0.4054 sec/batch
# Epoch 10/10 Iteration: 118300 Avg. Training loss: 3.9775 0.4066 sec/batch
# Epoch 10/10 Iteration: 118400 Avg. Training loss: 3.9657 0.4060 sec/batch
# Epoch 10/10 Iteration: 118500 Avg. Training loss: 3.9186 0.4106 sec/batch
# Epoch 10/10 Iteration: 118600 Avg. Training loss: 3.9861 0.4049 sec/batch
# Epoch 10/10 Iteration: 118700 Avg. Training loss: 3.9729 0.4045 sec/batch
# Epoch 10/10 Iteration: 118800 Avg. Training loss: 3.9443 0.4051 sec/batch
# Epoch 10/10 Iteration: 118900 Avg. Training loss: 3.9479 0.4065 sec/batch
# Epoch 10/10 Iteration: 119000 Avg. Training loss: 4.0024 0.4039 sec/batch
# Nearest to while: others, still, maintaining, retaining, working, trying, balkanization, attempting,
# Nearest to eight: nine, one, six, seven, three, four, five, two,
# Nearest to other: hand, each, disambiguation, uses, any, unlike, meanings, include,
# Nearest to these: include, none, were, are, included, enslavable, machines, barker,
# Nearest to where: situations, cases, moved, he, meets, place, places, spot,
# Nearest to people: living, china, republic, kills, ordinary, killing, births, killed,
# Nearest to will: continue, tend, likely, be, next, minestrone, continues, eventually,
# Nearest to b: leader, slovakian, nine, writer, gorden, sushi, sporty, monarchs,
# Nearest to road: roads, silk, nearest, pauli, street, stormont, traffic, safety,
# Nearest to police: officer, driving, officers, fire, mla, department, magma, thugs,
# Nearest to http: www, htm, org, html, edu, com, xico, index,
# Nearest to arts: fine, performing, art, kung, martial, combat, appliqu, silver,
# Nearest to shows: showing, show, states, vicuna, diagram, swung, kary, intermembrane,
# Nearest to engineering: engineers, engineer, miscarriage, technical, technologies, centimeter, doubtless, science,
# Nearest to channel: biased, auxiliary, raleigh, channels, piovra, wb, cable, halfway,
# Nearest to shown: studies, below, asterion, introducing, cinemas, filmed, displayed, exposures,
# Epoch 10/10 Iteration: 119100 Avg. Training loss: 4.0378 0.4167 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
